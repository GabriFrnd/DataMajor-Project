# %%
import os  # Interação com o sistema operacional
import sys  # Manipulação do caminho de busca de módulos

# Caminho (path) até o arquivo atual (explorer.ipynb)
actual_path = os.getcwd()

# Retorno do caminho (path) até a raiz do projeto
file_return = os.path.dirname(os.path.dirname(actual_path))

# Caminho (path) até a pasta 'transform' (pipeline/transform)
transform_path = os.path.join(file_return, 'pipeline', 'transform')

# Adição do caminho 'pipeline/transform' ao sys.path, permitindo a importação dos módulos
sys.path.append(transform_path)

# %%
# Importação da função 'transform', declarada no arquivo 'transform.py'
from transform import transform  # type: ignore

# Execução do pipeline de transformação
# Retorna o caminho do arquivo processado em 'data/processed/'
output_path = transform()
# Out:
# ...
#   DATA MAJOR — Pipeline Transform
# ...
# [1/6] Carregando dados brutos de: c:\Users\Giovanna\DataMajor-Project\data\raw\facebook_reviews.csv
#     → 355,748 linhas | 8 colunas carregadas
# [2/6] Removendo duplicatas...
#     → 9,542 duplicata(s) removida(s) | 346,206 linhas restantes
# [3/6] Tratando valores nulos...
#     → 29 linha(s) sem 'content' descartada(s)
#     → 61,143 nulo(s) em 'reviewCreatedVersion' preenchidos com 'desconhecida'
#     → 61,143 nulo(s) em 'appVersion' preenchidos com 'desconhecida'
# [4/6] Normalizando tipos de dados...
#     → Tipos ajustados com sucesso
# [5/6] Limpando e padronizando texto...
#     → Limpeza de texto concluída
# [6/6] Enriquecendo com colunas derivadas...
#     → Colunas adicionadas: review_length, word_count, sentiment, review_year, review_month
#
# ✅ Arquivo salvo em: c:\Users\Giovanna\DataMajor-Project\data\processed\facebook_reviews_clean.csv.gz
#    Tamanho: 23.2 MB | 346,177 linhas | 13 colunas
#
# Resumo do dataset processado:
# ...

# %%
import pandas as pd

# Carregamento do DataFrame processado para exploração
df = pd.read_csv(output_path)

# Visualização das primeiras linhas
df.head()
# Out:
#                                reviewId         userName  \
# 0  a5a86c6e-a877-40f2-850d-ca3734948774           Glydel
# 1  f8c762ce-fef3-4951-99df-077615cf83fc          KTM Pro
# 2  0eddf182-725a-45a9-b35a-eb44c20f1920  Michael Clausen
# 3  e81700a9-9fb9-401f-a98c-9060da81592b    Asri Arriffin
# 4  b290c064-f2af-4509-b425-0b6a1bca51a9    Angela Larsen
#
#                                              content  score  thumbsUpCount  \
# 0  when i open this app,my phone was collapsing.s...      1              2
# 1  This app is very engaging and keeps me connect...      5              0
# 2  certain content automatically increases the sc...      2            196
# 3  Bugs found. Video on comments freezes & the au...      1             13
# 4  all these new updates are causing so many glit...      2             10
#
#   reviewCreatedVersion                         at     appVersion  \
# 0        558.0.0.70.72  2026-05-03 07:56:00+00:00  558.0.0.70.72
# ...

# %%
# Informações gerais do DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 346177 entries, 0 to 346176
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              346177 non-null  str
#  1   userName              346174 non-null  str
#  2   content               346177 non-null  str
#  3   score                 346177 non-null  int64
#  4   thumbsUpCount         346177 non-null  int64
#  5   reviewCreatedVersion  346177 non-null  str
#  6   at                    346177 non-null  str
#  7   appVersion            346177 non-null  str
#  8   review_length         346177 non-null  int64
#  9   word_count            346177 non-null  int64
#  10  sentiment             346177 non-null  str
#  11  review_year           346177 non-null  int64
#  12  review_month          346177 non-null  int64
# dtypes: int64(6), str(7)
# memory usage: 34.3 MB

# %%
# Estatísticas descritivas das colunas numéricas
df.describe()
# Out:
#                score  thumbsUpCount  review_length     word_count  \
# count  346177.000000  346177.000000  346177.000000  346177.000000
# mean        3.900187      17.745385      48.333786       9.065143
# std         1.612615     482.199514      94.597999      17.393247
# min         1.000000       0.000000       1.000000       1.000000
# 25%         3.000000       0.000000       5.000000       1.000000
# 50%         5.000000       0.000000      11.000000       2.000000
# 75%         5.000000       0.000000      36.000000       7.000000
# max         5.000000  110743.000000    1328.000000     243.000000
#
#          review_year   review_month
# count  346177.000000  346177.000000
# mean     2023.947882       6.982367
# std         0.450452       1.730362
# min      2016.000000       1.000000
# 25%      2024.000000       6.000000
# 50%      2024.000000       7.000000
# 75%      2024.000000       8.000000
# max      2026.000000      12.000000

# %%
# Distribuição de sentimentos
df['sentiment'].value_counts()
# Out:
# sentiment
# positivo    243884
# negativo     82959
# neutro       19334
# Name: count, dtype: int64
