# %%
import os   # Interação com o sistema operacional
import sys  # Manipulação do caminho de busca de módulos

# Caminho (path) até o arquivo atual (explorer.ipynb)
actual_path = os.getcwd()

# Retorno do caminho (path) até a raiz do projeto
file_return = os.path.dirname(os.path.dirname(actual_path))

# Caminho (path) até a pasta 'transform' (pipeline/transform)
transform_path = os.path.join(file_return, 'pipeline', 'transform')

# Adição do caminho 'pipeline/transform' ao sys.path, permitindo a importação dos módulos
sys.path.append(transform_path)

# %%
# Importação da função 'transform', declarada no arquivo 'transform.py'
from transform import transform  # type: ignore

# Execução do pipeline de transformação
# Retorna o DataFrame processado e salva em 'data/processed/'
df = transform()
# Out:
# ==================================================
#   DATA MAJOR — Pipeline Transform
# ==================================================
# Dataset carregado: 355,773 linhas | 8 colunas
#
# [1/5] Duplicatas removidas: 9,542 | Linhas restantes: 346,231
# [2/5] Reviews sem texto descartadas: 29
#      Nulos em 'reviewCreatedVersion' preenchidos: 61,144
#      Nulos em 'appVersion' preenchidos: 61,144
# [3/5] Tipos normalizados com sucesso
# [4/5] Limpeza de texto concluída | Reviews vazias descartadas: 0
# [5/5] Colunas derivadas adicionadas: review_length, word_count, sentiment, review_year, review_month
#
# Arquivo salvo em: c:\Users\rodri\Projetos\DataMajor-Project\data\processed\facebook_reviews_clean.csv.gz
# Tamanho: 23.2 MB | 346,202 linhas | 13 colunas
# ==================================================

# %%
# Visualização das primeiras linhas do DataFrame processado
df.head()
# Out:
#                                reviewId         userName  \
# 0  6d8c5af9-e48a-4c63-9f68-98e1e658a357  Uddhav Bhasinge
# 1  df39cb1c-44ce-49f4-972b-e7cc2c44ff7d   Sandy Cummings
# 2  6fff7b38-a5b9-459c-a4b5-103fcb55866f     Kamran Siyal
# 3  0f59821f-f565-4014-a630-7df9a2beb691       James Bond
# 4  9bfda33d-2052-42b6-a857-015aac413b62    Francis Great
#
#                                              content  score  thumbsUpCount  \
# 0  Hello Dear Sir.. My Facebook Account is disabl...      4              0
# 1  The audio in a lot of the reels is awful! Plea...      4              1
# 2  very frustrating now a days Facebook suspended...      1              0
# 3  reels are now shared as a link instead of a vi...      1              0
# 4  “In this country where trust is hard to find, ...      5              0
#
#   reviewCreatedVersion                        at     appVersion  \
# 0        559.1.0.52.72 2026-05-07 07:58:04+00:00  559.1.0.52.72
# 1        559.1.0.52.72 2026-05-07 03:26:09+00:00  559.1.0.52.72
# 2        559.1.0.52.72 2026-05-07 03:12:07+00:00  559.1.0.52.72
# 3        558.0.0.70.72 2026-05-07 03:10:45+00:00  558.0.0.70.72
# 4        556.1.0.63.64 2026-05-07 02:32:04+00:00  556.1.0.63.64
#
#    review_length  word_count sentiment  review_year  review_month
# 0            496          86  positivo         2026             5
# 1            153          29  positivo         2026             5
# 2            106          16  negativo         2026             5
# 3             71          15  negativo         2026             5
# 4            162          26  positivo         2026             5

# %%
# Informações gerais do DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 346202 entries, 0 to 346201
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              346202 non-null  str
#  1   userName              346199 non-null  str
#  2   content               346202 non-null  str
#  3   score                 346202 non-null  int64
#  4   thumbsUpCount         346202 non-null  int64
#  5   reviewCreatedVersion  346202 non-null  str
#  6   at                    346202 non-null  datetime64[us, UTC]
#  7   appVersion            346202 non-null  str
#  8   review_length         346202 non-null  int64
#  9   word_count            346202 non-null  int64
#  10  sentiment             346202 non-null  str
#  11  review_year           346202 non-null  int32
#  12  review_month          346202 non-null  int32
# dtypes: datetime64[us, UTC](1), int32(2), int64(4), str(6)
# memory usage: 31.7 MB

# %%
# Estatísticas descritivas das colunas numéricas
df.describe()
# Out:
#                score  thumbsUpCount  review_length    word_count  \
# count  346202.000000  346202.000000  346202.000000  346202.00000
# mean        3.900041      17.744135      48.345665       9.06725
# std         1.612692     482.182126      94.613831      17.39584
# min         1.000000       0.000000       1.000000       1.00000
# 25%         3.000000       0.000000       5.000000       1.00000
# 50%         5.000000       0.000000      11.000000       2.00000
# 75%         5.000000       0.000000      36.000000       7.00000
# max         5.000000  110743.000000    1328.000000     243.00000
#
#          review_year   review_month
# count  346202.000000  346202.000000
# mean     2023.948030       6.982224
# std         0.450774       1.730382
# min      2016.000000       1.000000
# 25%      2024.000000       6.000000
# 50%      2024.000000       7.000000
# 75%      2024.000000       8.000000
# max      2026.000000      12.000000

# %%
# Distribuição de sentimentos
df['sentiment'].value_counts()
# Out:
# sentiment
# positivo    243889
# negativo     82977
# neutro       19336
# Name: count, dtype: int64
